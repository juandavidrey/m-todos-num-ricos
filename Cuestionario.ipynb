# %% [markdown]
# #9.1
# #a)
# $
# \begin{pmatrix}
# 0 & 2 & 5 \\
# 1 & 0 & 1 \\
# 8 & 3 & 0
# \end{pmatrix}
# $
# $
# \begin{pmatrix}
# x_1\\
# x_2\\
# x_3
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 50\\
# 10\\
# 20
# \end{pmatrix}
# $
# #b)
# $
# \begin{pmatrix}
# 0 & 1 & 8 \\
# 2 & 0 & 3 \\
# 5 & 1 & 0
# \end{pmatrix}
# $

# %% [markdown]
# #9.2
# #a)
# $$A = 3x2 , B = 3x3 , C = 3x1 , D = 2x4 , E = 3x3 , F = 2x3 , G = 1x3$$
# #b)
# $Matrices \hspace{2mm} cuadradas = B \hspace{2mm} y \hspace{2mm} E \hspace{4mm}
# Matrices \hspace{2mm} columna = C \hspace{4mm}
# Matrices \hspace{2mm} renglon = G$
# #c)
# $$a_{12} = 7, b_{23} = 7, d_{32} = no \hspace{2mm} existe, e_{22} = 2, f_{12} = 0, g_{12} = 6$$
# #d)
# ###1)
# $
# \begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}
# $
# +
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 5 & 8 & 15 \\
# 8 & 4 & 10 \\
# 5 & 0 & 10
# \end{pmatrix}
# $
# ###2) $$dimension \hspace{2mm} de \hspace{2mm} las \hspace{2mm} matrices \hspace{2mm} diferentes$$
# ###3)
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# -
# $
# \begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 3 & -2 & -1 \\
# -6 & 0 & 4 \\
# -3 & 0 & -2
# \end{pmatrix}
# $
# ###4)
# 7
# x
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 28 & 21 & 49 \\
# 7 & 14 & 49 \\
# 7 & 0 & 28
# \end{pmatrix}
# $
# ###5)
# $
# \begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 17 & 13 & 74 \\
# 33 & 25 & 75 \\
# 22 & 12 & 52
# \end{pmatrix}
# $
# ###6)
# $
# \begin{pmatrix}
# 3 & 6 & 1
# \end{pmatrix}
# $
# ###7)
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 4 & 7 \\
# 1 & 2  \\
# 5 & 6
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 54 & 76 \\
# 41 & 53  \\
# 24 & 31
# \end{pmatrix}
# $
# ###8)
# $
# \begin{pmatrix}
# 9 & 2 \\
# 4 & -1  \\
# 3 & 7  \\
# -6 & 5
# \end{pmatrix}
# $
# ###9)
# El numero de columnas de A no equivale a numero de columnas de B
# ###10)
# $
# \begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}
# $
# ###11)
# $
# \begin{pmatrix}
# 1 & 7 & 4 \\
# 5 & 2 & 0 \\
# 8 & 3 & 6
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 66 & 19 & 53 \\
# 19 & 29 & 46 \\
# 53 & 46 & 109
# \end{pmatrix}
# $
# ###12)
# $
# \begin{pmatrix}
# 3 & 6 & 1
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 3 \\
# 6\\
# 1
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 46
# \end{pmatrix}
# $

# %% [markdown]
# #9.3
# ###a)
# $$AxB$$
# $
# \begin{pmatrix}
# 1 & 6  \\
# 3 & 10 \\
# 7 & 4
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 1 & 3  \\
# 0.5 & 2
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 4 & 15  \\
# 8 & 29 \\
# 9 & 29
# \end{pmatrix}
# $
# $$AxC$$
# $
# \begin{pmatrix}
# 1 & 6  \\
# 3 & 10 \\
# 7 & 4
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 2 & -2  \\
# -3 & 1
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# -16 & 4  \\
# -24 & 4 \\
# 2 & -10
# \end{pmatrix}
# $
# $$BxC$$
# $
# \begin{pmatrix}
# 1 & 3  \\
# 0.5 & 2
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 2 & -2  \\
# -3 & 1
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# -7 & 1  \\
# -5 & 1
# \end{pmatrix}
# $
# $$CxB$$
# $
# \begin{pmatrix}
# 2 & -2  \\
# -3 & 1
# \end{pmatrix}
# $
# x
# $
# \begin{pmatrix}
# 1 & 3  \\
# 0.5 & 2
# \end{pmatrix}
# $
# =
# $
# \begin{pmatrix}
# 1 & 2  \\
# -2.5 & -7
# \end{pmatrix}
# $
# ###b)$ \text{Es imposible multiplicar dos matrices si el número de columnas de la primera matriz no es igual al número de renglones en la segunda matriz.}$

# %% [markdown]
# #9.6
# ###a)
# $D = 0x_1
# \begin{vmatrix}
# 1 & 1\\
# 1 & 0
# \end{vmatrix}
# -
# 2x_2
# \begin{vmatrix}
# 2 & 1\\
# 3 & 0
# \end{vmatrix}
# +
# 2x_3
# \begin{vmatrix}
# 2 & 1\\
# 3 & 1
# \end{vmatrix}
# =
# 0 - (2x_2)(0-(1*3)) + (2x_3)((2*1)-(3*1))
# = 1
# $
# ###b)
# $D =
# \begin{vmatrix}
# 0 & 2 & 5 \\
# 2 & 1 & 1 \\
# 3 & 1 & 0
# \end{vmatrix}
# $
# = 1
# $$
# x_1 =
# \frac{
# \begin{vmatrix}
# 9 & 5 & 8 \\
# 9 & 2 & 3 \\
# 10 & 0 & 6
# \end{vmatrix}}
# {1}
# =
# 6 ;
# x_2 =
# \frac{
# \begin{vmatrix}
# 0 & 9 & 5 \\
# 2 & 9 & 1 \\
# 3 & 10 & 0
# \end{vmatrix}}
# {1}
# =
# -8 ;
# x_3 =
# \frac{
# \begin{vmatrix}
# 0 & 2 & 9 \\
# 2 & 1 & 9 \\
# 3 & 1 & 10
# \end{vmatrix}}
# {1}
# =
# 5
# $$
# ###c)
# $$0(6)+2(-8)+5(5)=9$$
# $$2(6)+1(-8)+1(5)=9$$
# $$3(6)+1(-8)+0(5)=10$$

# %% [markdown]
# #9.8
# ###a)
# $$\text{10$x_1$ + 2$x_2$ – $x_3$ = 27 (1)}$$
# $$\text{–3$x_1$ – 6$x_2$ + 2$x_3$ = –61.5 (2)}$$
# $$\text{$x_1$ + $x_2$ + 5$x_3$ = –21.5} (3)$$
# $$\text{1. Multiplicar (1) por $\frac{-3}{10}$ y sumarla a (2)}$$
# $$\text{2. Multiplicar (1) por $\frac{1}{10}$ y restarla a (3)}$$
# $$\text{10$x_1$ + 2$x_2$ – $x_3$ = 27 (4)}$$
# $$\text{0  - $\frac{27}{5}$$x_2$ + $\frac{17}{10}$$x_3$ = $\frac{-267}{5}$ (5)}$$
# $$\text{0 - $\frac{4}{5}$$x_2$ - $\frac{51}{10}$$x_3$ = $\frac{121}{5}$} (6)$$
# $$\text{3. Multiplicar (5) por $\frac{4}{27}$ y restarla a (6)}$$
# $$\text{10$x_1$ + 2$x_2$ – $x_3$ = 27 (7)}$$
# $$\text{0  - $\frac{27}{5}$$x_2$ + $\frac{17}{10}$$x_3$ = $\frac{-267}{5}$ (8)}$$
# $$\text{0 - 0 + $\frac{289}{54}$$x_3$ = $\frac{-289}{9}$} (9)$$
# $$\text{3. Despejar  $x_3$ de (9) }$$
# $$x_3 = \frac{-289}{9} \div \frac{289}{54} = -6 $$
# $$\text{4. Sustitiur ese valor en  (8) y despejar $x_2$}$$
# $$x_2 = \frac{-267}{5} \div \frac{51}{5} = 8 $$
# $$\text{5. Reemplazar estos valores en  (1) y despejar $x_2$}$$
# $$x_1 = \frac{27 - 16 - 6}{10} = \frac{1}{2} $$
# ###b)
# $$\text{10($\frac{1}{2}$) + 2(8) – (-6)$x_3$ = 27}$$
